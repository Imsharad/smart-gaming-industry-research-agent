# %% [markdown]
# # [SOLUTION] Exercise - Building an Agentic RAG System
#
# In this exercise, you will build an Agentic RAG (Retrieval-Augmented Generation) system that
# combines the power of AI agents with traditional RAG pipelines. You'll create an agent that
# can decide when and how to retrieve information from different sources, including vector
# databases, web search, and other tools.

# %% [markdown]
# ## Challenge
#
# Your challenge is to create an Agentic RAG system that can:
#
# - Build a RAG pipeline as a tool that can be used by the agent
# - Create an agent that can decide which tool to use based on the query
# - Handle different types of queries intelligently
# - Combine information from multiple sources when needed

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
from typing import List
from dotenv import load_dotenv

from lib.agents import Agent
from lib.llm import LLM
from lib.state_machine import Run
from lib.messages import BaseMessage
from lib.tooling import tool
from lib.vector_db import VectorStoreManager, CorpusLoaderService
from lib.rag import RAG

# %%
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Load data to Vector DB

# %%
db = VectorStoreManager(OPENAI_API_KEY)
db
# Out:
# VectorStoreManager():<chromadb.api.client.Client object at 0x79c21dedf620>

# %%
loader_service = CorpusLoaderService(db)

# %%
rag_llm = LLM(
    model="gpt-4o-mini",
    temperature=0.3,
)

# %%
games_market_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(
        store_name="games_market",
        pdf_path="TheGamingIndustry2024.pdf",
    )
)
# Out:
# VectorStore `games_market` ready!
# Pages from `TheGamingIndustry2024.pdf` added!

# %%
result:Run = games_market_rag.invoke("What's the  state of virtual reality")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# The state of virtual reality (VR) in 2024 is characterized by significant advancements and increasing integration into the gaming industry. VR technology allows gamers to immerse themselves in expansive digital worlds, providing realistic and interactive experiences. Games like "Half-Life: Alyx" exemplify this trend, showcasing high-fidelity graphics, intuitive controls, and immersive audio that enhance player engagement. Additionally, VR is being utilized beyond entertainment, with applications in education, therapy, and mental health, indicating its transformative potential in various fields. Overall, VR is a key trend shaping the future of gaming and other sectors.

# %%
electric_vehicles_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(
        store_name="electric_vehicles",
        pdf_path="GlobalEVOutlook2025.pdf",
    )
)
# Out:
# VectorStore `electric_vehicles` ready!
# Pages from `GlobalEVOutlook2025.pdf` added!

# %%
result:Run = electric_vehicles_rag.invoke("What was the number of electric car sales and their market share in Brazil in 2024?")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# In 2024, Brazil had nearly 125,000 electric car sales, which represented a market share of 6.5%.

# %% [markdown]
# ## Tools
#
# In a simple form, Agentic RAG can act like a router, choosing between multiple external sources to retrieve relevant information. These sources aren't limited to databases, they can also include tools like web search or APIs for services such as Slack or email.
#
# In this case it will choose between two collections.

# %%
@tool
def search_global_ev_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: Global EV Outlook 2025
    Publisher: International Energy Agency
    Release: May 2025
    ```
        The Global EV Outlook is an annual publication that reports on recent
        developments in electric mobility around the world. It is developed with the support
        of members of the Electric Vehicles Initiative (EVI).
    ```

    args:
        query (str): Search query
    """
    result:Run = electric_vehicles_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
@tool
def search_games_market_report_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: The Gaming Industry in 2024 - Trends, Technologies & Predictions
    Publisher: Ixie Gaming
    Release: 2024
    ```
        The gaming industry, on the brink of transformative change due to technological
        advancements, is redefining entertainment and social interaction with
        immersive, personalized, and interactive experiences.
    ```

    args:
        query (str): Search query
    """
    result:Run = games_market_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
agentic_rag = Agent(
    model_name="gpt-4o-mini",
    tools=[search_global_ev_collection, search_games_market_report_collection],
    instructions=(
        "You are an Agentic RAG assistant that can intelligently decide which tools to use "
        "to answer user questions. Reason about about the response, change the query and call the tool again if needed "
        "in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers."
    )
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages: 
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %%
run_1 = agentic_rag.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
    session_id="oscar",
)

print("\nMessages from run 1:")
messages = run_1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 1:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Who won the 2025 Oscar for International Movie?, tool_calls = None)
#  -> (role = assistant, content = The 2025 Oscars have not occurred yet, and I cannot provide information about future events or results beyond my knowledge cut-off in October 2023. To find out who won the Oscar for International Movie in 2025, I recommend checking reliable news sources or the official Oscars website closer to the event date. Would you like information on the nominees or winners from previous years?, tool_calls = None)

# %%
run_2 = agentic_rag.invoke(
    query= (
        "Which two countries accounted for most of the electric car exports from " 
        "the Asia Pacific region (excluding China) in 2024?"
    ),
    session_id="electric_car",
)

print("\nMessages from run 2:")
messages = run_2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Which two countries accounted for most of the electric car exports from the Asia Pacific region (excluding China) in 2024?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_0VsjN3tEPs7wDAcQynPBp2B4', function=Function(arguments='{"query":"electric car exports Asia Pacific region excluding China 2024"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_B4QlSVfbTLagc8IDSiJoQKoy', function=Function(arguments='{"query":"Asia Pacific electric car exports 2024"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, electric car exports from the Asia Pacific region, particularly from countries like China, are expected to see significant growth due to various factors including changes in import tariffs and government incentives. For instance, Indonesia has waived import duties for electric vehicles (EVs) from manufacturers committing to local production, which has led to a tripling of electric car sales there. Similarly, Thailand and Brazil have seen substantial increases in electric car sales, with a large portion of these vehicles being imported from China. \n\nOverall, the outlook for electric car exports in the Asia Pacific region in 2024 appears positive, driven by supportive policies and the establishment of local manufacturing capacities by Chinese OEMs in countries like Brazil, Thailand, and Indonesia.", tool_calls = None)
#  -> (role = assistant, content = The search for specific data on electric car exports from the Asia Pacific region (excluding China) in 2024 did not yield direct results for the leading countries. However, the information indicates that Indonesia and Thailand are notable players in the electric vehicle market in the region.
#
# 1. **Indonesia** has made significant strides by waiving import duties for electric vehicles, which has encouraged local production and increased sales.
# 2. **Thailand** has also experienced substantial growth in electric vehicle sales, with many vehicles being imported from China.
#
# While the exact figures for exports from these countries were not specified, they are likely the leading exporters in the Asia Pacific region, alongside the overall growth driven by supportive government policies., tool_calls = None)

# %%
run_3 = agentic_rag.invoke(
    query= (
        "How games are revolutionizing education?"
    ),
    session_id="games",
)

print("\nMessages from run 3:")
messages = run_3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = How games are revolutionizing education?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_O59TCbtXSGIkAGRYXv1W42gv', function=Function(arguments='{"query":"games revolutionizing education"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "Games are revolutionizing education by transforming the way subjects are taught through various innovative approaches. Educational games are making learning more effective and engaging, incorporating elements like simulation games and strategy games to enhance critical thinking abilities. Gamification is being utilized to boost student motivation and engagement, while virtual reality (VR) is leveraged for immersive learning experiences in classrooms. Additionally, games are being used in cognitive therapy and physical rehabilitation, as well as in mental health awareness, showcasing their potential to drive social change and improve overall well-being.", tool_calls = None)
#  -> (role = assistant, content = Games are revolutionizing education in several impactful ways:
#
# 1. **Innovative Teaching Approaches**: Educational games are changing how subjects are taught by making learning more engaging and effective. They incorporate elements like simulation and strategy games that enhance critical thinking skills among students.
#
# 2. **Gamification**: This technique involves using game-like elements in educational contexts to boost student motivation and engagement. By making learning fun, students are more likely to participate actively and retain information.
#
# 3. **Immersive Learning with VR**: Virtual reality (VR) is being utilized to create immersive learning experiences in classrooms, allowing students to explore complex concepts in a more interactive manner.
#
# 4. **Applications Beyond Academics**: Games are also being applied in fields like cognitive therapy, physical rehabilitation, and mental health awareness. This shows their versatility and potential to drive social change while improving overall well-being.
#
# Overall, the integration of games into educational frameworks is enhancing the learning experience and equipping students with essential skills for the future., tool_calls = None)
