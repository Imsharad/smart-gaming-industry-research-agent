# %% [markdown]
# # [SOLUTION] Exercise - Create an Agent with external API call enabled
#
# In this exercise, you'll build an agent that can interact with external APIs to gather real-time data
# and provide responses based on that information. You'll combine concepts from state management and
# memory while adding the ability to make external API calls safely and effectively.

# %% [markdown]
# ## Challenge
#
# Your task is to create an agent that can make External API Calls:
#
# - Implement tools that interact with real APIs
# - Handle API responses and errors gracefully
# - Use environment variables for API keys
# - Process and format API data for user consumption

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
import os
import random
from typing import List
import requests
from dotenv import load_dotenv

from lib.agents import Agent
from lib.messages import BaseMessage
from lib.tooling import tool

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Define API tools

# %% [markdown]
# Feel free to use any open service available through APIs.
#
# Here are a few examples. You can follow the instructions given.
# - https://jsonplaceholder.typicode.com/guide/
# - https://www.exchangerate-api.com/
# - https://openweathermap.org/
#
# Or you can find one you're interested in here.
# - https://github.com/public-apis/public-apis

# %%
@tool
def get_weather(city: str) -> dict:
    """
    Get current weather for a city using OpenWeather API
    args:
        city (str): Name of the city to get weather for
    """
    API_KEY = os.getenv("OPENWEATHER_API_KEY")
    BASE_URL = "http://api.weatherapi.com/v1/current.json"
    
    params = {
        "q": city,
        "key": API_KEY,
        "units": "metric",
        "aqi":"no"
    }
    
    response = requests.get(BASE_URL, params=params)
    response.raise_for_status()
    return response.json()

# %%
@tool
def get_exchange_rate(from_currency: str = "USD") -> dict:
    """
    Get latest exchange rates from a base currency
    args:
        from_currency (str): Base currency code (default: USD)
    """
    API_KEY = os.getenv("EXCHANGERATE_API_KEY")
    BASE_URL = "https://v6.exchangerate-api.com/v6"
    
    url = f"{BASE_URL}/{API_KEY}/latest/{from_currency}"
    response = requests.get(url)
    response.raise_for_status()
    return response.json()

# %%
@tool
def get_random_pokemon() -> dict:
    """Get a random Pokemon from the original 151"""
    URL = "https://pokeapi.co/api/v2/pokemon?limit=151"
    response = requests.get(URL)
    response.raise_for_status()
    return random.choice(response.json()['results'])

# %%
tools = [get_weather, get_exchange_rate, get_random_pokemon]

# %%
agent = Agent(
    model_name="gpt-4o-mini",
    instructions=(
        "You are an assistant that can help with:\n"
        "1. Getting weather information for cities\n"
        "2. Checking currency exchange rates\n"
        "3. Getting a random Pokemon\n"
        "Use the available tools to help answer questions about these topics.\n"
        "Maintain context across conversations within the same session."
    ),
    tools=tools
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages:
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %% [markdown]
# ## Run your Agent

# %%
session_id = "external_tools"

# %%
run1 = agent.invoke(
    query="What's the weather like in Thiruvananthapuram?", 
    session_id=session_id,
)

print("\nMessages from run 1:")
messages = run1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 1:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the weather like in Panaji?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 73.8333, 'lat': 15.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 25, 'feels_like': 25.46, 'temp_min': 25, 'temp_max': 25, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 3000, 'wind': {'speed': 2.06, 'deg': 20}, 'clouds': {'all': 73}, 'dt': 1766592230, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1766539674, 'sunset': 1766580019}, 'timezone': 19800, 'id': 1260607, 'name': 'Panjim', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Panaji is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 25°C
# - **Feels Like**: 25.5°C
# - **Humidity**: 73%
# - **Wind Speed**: 2.06 m/s from the northeast
# - **Visibility**: 3000 meters
# - **Cloud Cover**: 73%
#
# If you need any more information, feel free to ask!, tool_calls = None)
#  -> (role = user, content = What's the weather like in Thiruvananthapuram?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 76.9167, 'lat': 8.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 27.99, 'feels_like': 31.19, 'temp_min': 27.99, 'temp_max': 27.99, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 4000, 'wind': {'speed': 0.51, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1766592289, 'sys': {'type': 1, 'id': 9226, 'country': 'IN', 'sunrise': 1766538175, 'sunset': 1766580037}, 'timezone': 19800, 'id': 1254163, 'name': 'Trivandrum', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Thiruvananthapuram is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 28°C
# - **Feels Like**: 31.2°C
# - **Humidity**: 74%
# - **Wind Speed**: 0.51 m/s (calm)
# - **Visibility**: 4000 meters
# - **Cloud Cover**: 20%
#
# If you have any other questions or need further information, just let me know!, tool_calls = None)

# %%
run2 = agent.invoke(
    query="What's the exchange rate from USD to EUR?", 
    session_id=session_id,
)
print("\nMessages from run 2:")
messages = run2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the weather like in Panaji?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 73.8333, 'lat': 15.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 25, 'feels_like': 25.46, 'temp_min': 25, 'temp_max': 25, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 3000, 'wind': {'speed': 2.06, 'deg': 20}, 'clouds': {'all': 73}, 'dt': 1766592230, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1766539674, 'sunset': 1766580019}, 'timezone': 19800, 'id': 1260607, 'name': 'Panjim', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Panaji is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 25°C
# - **Feels Like**: 25.5°C
# - **Humidity**: 73%
# - **Wind Speed**: 2.06 m/s from the northeast
# - **Visibility**: 3000 meters
# - **Cloud Cover**: 73%
#
# If you need any more information, feel free to ask!, tool_calls = None)
#  -> (role = user, content = What's the weather like in Thiruvananthapuram?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 76.9167, 'lat': 8.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 27.99, 'feels_like': 31.19, 'temp_min': 27.99, 'temp_max': 27.99, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 4000, 'wind': {'speed': 0.51, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1766592289, 'sys': {'type': 1, 'id': 9226, 'country': 'IN', 'sunrise': 1766538175, 'sunset': 1766580037}, 'timezone': 19800, 'id': 1254163, 'name': 'Trivandrum', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Thiruvananthapuram is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 28°C
# - **Feels Like**: 31.2°C
# - **Humidity**: 74%
# - **Wind Speed**: 0.51 m/s (calm)
# - **Visibility**: 4000 meters
# - **Cloud Cover**: 20%
#
# If you have any other questions or need further information, just let me know!, tool_calls = None)
#  -> (role = user, content = What's the exchange rate from USD to EUR?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])
#  -> (role = tool, content = "{'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1766534402, 'time_last_update_utc': 'Wed, 24 Dec 2025 00:00:02 +0000', 'time_next_update_unix': 1766620802, 'time_next_update_utc': 'Thu, 25 Dec 2025 00:00:02 +0000', 'base_code': 'USD', 'conversion_rates': {'USD': 1, 'AED': 3.6725, 'AFN': 66.0912, 'ALL': 81.9657, 'AMD': 381.3869, 'ANG': 1.79, 'AOA': 922.5811, 'ARS': 1452.25, 'AUD': 1.4938, 'AWG': 1.79, 'AZN': 1.6999, 'BAM': 1.6592, 'BBD': 2.0, 'BDT': 122.1403, 'BGN': 1.6592, 'BHD': 0.376, 'BIF': 2957.4546, 'BMD': 1.0, 'BND': 1.2853, 'BOB': 6.9204, 'BRL': 5.588, 'BSD': 1.0, 'BTN': 89.6634, 'BWP': 13.5442, 'BYN': 2.9163, 'BZD': 2.0, 'CAD': 1.3696, 'CDF': 2252.7623, 'CHF': 0.7883, 'CLF': 0.02298, 'CLP': 908.5106, 'CNH': 7.0222, 'CNY': 7.0386, 'COP': 3800.8015, 'CRC': 495.2509, 'CUP': 24.0, 'CVE': 93.5398, 'CZK': 20.6199, 'DJF': 177.721, 'DKK': 6.3313, 'DOP': 62.513, 'DZD': 129.6195, 'EGP': 47.5038, 'ERN': 15.0, 'ETB': 154.5401, 'EUR': 0.8483, 'FJD': 2.277, 'FKP': 0.7406, 'FOK': 6.3319, 'GBP': 0.7406, 'GEL': 2.6953, 'GGP': 0.7406, 'GHS': 11.3645, 'GIP': 0.7406, 'GMD': 74.2439, 'GNF': 8736.1844, 'GTQ': 7.656, 'GYD': 209.0698, 'HKD': 7.778, 'HNL': 26.3414, 'HRK': 6.3916, 'HTG': 130.8887, 'HUF': 331.3655, 'IDR': 16761.3566, 'ILS': 3.1914, 'IMP': 0.7406, 'INR': 89.6676, 'IQD': 1309.005, 'IRR': 42351.2057, 'ISK': 125.609, 'JEP': 0.7406, 'JMD': 159.4908, 'JOD': 0.709, 'JPY': 156.2209, 'KES': 128.8497, 'KGS': 87.3942, 'KHR': 4008.6044, 'KID': 1.4938, 'KMF': 417.345, 'KRW': 1480.9932, 'KWD': 0.3069, 'KYD': 0.8333, 'KZT': 509.9681, 'LAK': 21637.6656, 'LBP': 89500.0, 'LKR': 309.221, 'LRD': 176.9852, 'LSL': 16.6873, 'LYD': 5.4251, 'MAD': 9.1207, 'MDL': 16.8554, 'MGA': 4554.5991, 'MKD': 52.2523, 'MMK': 2101.1224, 'MNT': 3535.243, 'MOP': 8.0116, 'MRU': 39.8448, 'MUR': 45.9802, 'MVR': 15.45, 'MWK': 1738.7992, 'MXN': 17.9248, 'MYR': 4.0636, 'MZN': 63.7327, 'NAD': 16.6873, 'NGN': 1453.7702, 'NIO': 36.784, 'NOK': 10.0418, 'NPR': 143.4615, 'NZD': 1.7126, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.3649, 'PGK': 4.2932, 'PHP': 58.8221, 'PKR': 280.1038, 'PLN': 3.5818, 'PYG': 6773.6632, 'QAR': 3.64, 'RON': 4.3188, 'RSD': 99.6633, 'RUB': 78.1428, 'RWF': 1456.9765, 'SAR': 3.75, 'SBD': 8.0401, 'SCR': 13.9984, 'SDG': 543.6227, 'SEK': 9.1739, 'SGD': 1.2852, 'SHP': 0.7406, 'SLE': 24.1139, 'SLL': 24113.8848, 'SOS': 570.1545, 'SRD': 38.4981, 'SSP': 4619.8648, 'STN': 20.7838, 'SYP': 11027.7855, 'SZL': 16.6873, 'THB': 31.1285, 'TJS': 9.2311, 'TMT': 3.4985, 'TND': 2.8886, 'TOP': 2.3885, 'TRY': 42.8752, 'TTD': 6.7844, 'TVD': 1.4938, 'TWD': 31.5169, 'TZS': 2469.9945, 'UAH': 42.12, 'UGX': 3588.5175, 'UYU': 39.0635, 'UZS': 12073.0149, 'VES': 291.3524, 'VND': 26220.994, 'VUV': 120.5026, 'WST': 2.7512, 'XAF': 556.4599, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.7252, 'XOF': 556.4599, 'XPF': 101.2314, 'YER': 238.3491, 'ZAR': 16.6864, 'ZMW': 22.5079, 'ZWG': 26.0482, 'ZWL': 26.0482}}", tool_calls = None)
#  -> (role = assistant, content = The current exchange rate from USD to EUR is approximately **0.8483 EUR** for 1 USD. If you need any further information or have more questions, feel free to ask!, tool_calls = None)

# %%
run3 = agent.invoke(
    query="Pick one random Pokemon!", 
    session_id=session_id,
)
print("\nMessages from run 3:")
messages = run3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the weather like in Panaji?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 73.8333, 'lat': 15.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 25, 'feels_like': 25.46, 'temp_min': 25, 'temp_max': 25, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 3000, 'wind': {'speed': 2.06, 'deg': 20}, 'clouds': {'all': 73}, 'dt': 1766592230, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1766539674, 'sunset': 1766580019}, 'timezone': 19800, 'id': 1260607, 'name': 'Panjim', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Panaji is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 25°C
# - **Feels Like**: 25.5°C
# - **Humidity**: 73%
# - **Wind Speed**: 2.06 m/s from the northeast
# - **Visibility**: 3000 meters
# - **Cloud Cover**: 73%
#
# If you need any more information, feel free to ask!, tool_calls = None)
#  -> (role = user, content = What's the weather like in Thiruvananthapuram?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 76.9167, 'lat': 8.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 27.99, 'feels_like': 31.19, 'temp_min': 27.99, 'temp_max': 27.99, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 4000, 'wind': {'speed': 0.51, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1766592289, 'sys': {'type': 1, 'id': 9226, 'country': 'IN', 'sunrise': 1766538175, 'sunset': 1766580037}, 'timezone': 19800, 'id': 1254163, 'name': 'Trivandrum', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Thiruvananthapuram is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 28°C
# - **Feels Like**: 31.2°C
# - **Humidity**: 74%
# - **Wind Speed**: 0.51 m/s (calm)
# - **Visibility**: 4000 meters
# - **Cloud Cover**: 20%
#
# If you have any other questions or need further information, just let me know!, tool_calls = None)
#  -> (role = user, content = What's the exchange rate from USD to EUR?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])
#  -> (role = tool, content = "{'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1766534402, 'time_last_update_utc': 'Wed, 24 Dec 2025 00:00:02 +0000', 'time_next_update_unix': 1766620802, 'time_next_update_utc': 'Thu, 25 Dec 2025 00:00:02 +0000', 'base_code': 'USD', 'conversion_rates': {'USD': 1, 'AED': 3.6725, 'AFN': 66.0912, 'ALL': 81.9657, 'AMD': 381.3869, 'ANG': 1.79, 'AOA': 922.5811, 'ARS': 1452.25, 'AUD': 1.4938, 'AWG': 1.79, 'AZN': 1.6999, 'BAM': 1.6592, 'BBD': 2.0, 'BDT': 122.1403, 'BGN': 1.6592, 'BHD': 0.376, 'BIF': 2957.4546, 'BMD': 1.0, 'BND': 1.2853, 'BOB': 6.9204, 'BRL': 5.588, 'BSD': 1.0, 'BTN': 89.6634, 'BWP': 13.5442, 'BYN': 2.9163, 'BZD': 2.0, 'CAD': 1.3696, 'CDF': 2252.7623, 'CHF': 0.7883, 'CLF': 0.02298, 'CLP': 908.5106, 'CNH': 7.0222, 'CNY': 7.0386, 'COP': 3800.8015, 'CRC': 495.2509, 'CUP': 24.0, 'CVE': 93.5398, 'CZK': 20.6199, 'DJF': 177.721, 'DKK': 6.3313, 'DOP': 62.513, 'DZD': 129.6195, 'EGP': 47.5038, 'ERN': 15.0, 'ETB': 154.5401, 'EUR': 0.8483, 'FJD': 2.277, 'FKP': 0.7406, 'FOK': 6.3319, 'GBP': 0.7406, 'GEL': 2.6953, 'GGP': 0.7406, 'GHS': 11.3645, 'GIP': 0.7406, 'GMD': 74.2439, 'GNF': 8736.1844, 'GTQ': 7.656, 'GYD': 209.0698, 'HKD': 7.778, 'HNL': 26.3414, 'HRK': 6.3916, 'HTG': 130.8887, 'HUF': 331.3655, 'IDR': 16761.3566, 'ILS': 3.1914, 'IMP': 0.7406, 'INR': 89.6676, 'IQD': 1309.005, 'IRR': 42351.2057, 'ISK': 125.609, 'JEP': 0.7406, 'JMD': 159.4908, 'JOD': 0.709, 'JPY': 156.2209, 'KES': 128.8497, 'KGS': 87.3942, 'KHR': 4008.6044, 'KID': 1.4938, 'KMF': 417.345, 'KRW': 1480.9932, 'KWD': 0.3069, 'KYD': 0.8333, 'KZT': 509.9681, 'LAK': 21637.6656, 'LBP': 89500.0, 'LKR': 309.221, 'LRD': 176.9852, 'LSL': 16.6873, 'LYD': 5.4251, 'MAD': 9.1207, 'MDL': 16.8554, 'MGA': 4554.5991, 'MKD': 52.2523, 'MMK': 2101.1224, 'MNT': 3535.243, 'MOP': 8.0116, 'MRU': 39.8448, 'MUR': 45.9802, 'MVR': 15.45, 'MWK': 1738.7992, 'MXN': 17.9248, 'MYR': 4.0636, 'MZN': 63.7327, 'NAD': 16.6873, 'NGN': 1453.7702, 'NIO': 36.784, 'NOK': 10.0418, 'NPR': 143.4615, 'NZD': 1.7126, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.3649, 'PGK': 4.2932, 'PHP': 58.8221, 'PKR': 280.1038, 'PLN': 3.5818, 'PYG': 6773.6632, 'QAR': 3.64, 'RON': 4.3188, 'RSD': 99.6633, 'RUB': 78.1428, 'RWF': 1456.9765, 'SAR': 3.75, 'SBD': 8.0401, 'SCR': 13.9984, 'SDG': 543.6227, 'SEK': 9.1739, 'SGD': 1.2852, 'SHP': 0.7406, 'SLE': 24.1139, 'SLL': 24113.8848, 'SOS': 570.1545, 'SRD': 38.4981, 'SSP': 4619.8648, 'STN': 20.7838, 'SYP': 11027.7855, 'SZL': 16.6873, 'THB': 31.1285, 'TJS': 9.2311, 'TMT': 3.4985, 'TND': 2.8886, 'TOP': 2.3885, 'TRY': 42.8752, 'TTD': 6.7844, 'TVD': 1.4938, 'TWD': 31.5169, 'TZS': 2469.9945, 'UAH': 42.12, 'UGX': 3588.5175, 'UYU': 39.0635, 'UZS': 12073.0149, 'VES': 291.3524, 'VND': 26220.994, 'VUV': 120.5026, 'WST': 2.7512, 'XAF': 556.4599, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.7252, 'XOF': 556.4599, 'XPF': 101.2314, 'YER': 238.3491, 'ZAR': 16.6864, 'ZMW': 22.5079, 'ZWG': 26.0482, 'ZWL': 26.0482}}", tool_calls = None)
#  -> (role = assistant, content = The current exchange rate from USD to EUR is approximately **0.8483 EUR** for 1 USD. If you need any further information or have more questions, feel free to ask!, tool_calls = None)
#  -> (role = user, content = Pick one random Pokemon!, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_Z2kpkgHyI3po01XG60BSOXTB', function=Function(arguments='{}', name='get_random_pokemon'), type='function')])
#  -> (role = tool, content = "{'name': 'tentacruel', 'url': 'https://pokeapi.co/api/v2/pokemon/73/'}", tool_calls = None)
#  -> (role = assistant, content = You got a random Pokémon: **Tentacruel**!
#
# If you want to know more about Tentacruel or need anything else, just let me know!, tool_calls = None)

# %% [markdown]
# ## Check session histories

# %%
runs = agent.get_session_runs(session_id)
for i, run_object in enumerate(runs, 1):
    print(f"\n# Run {i}", run_object.metadata)
    print("Messages:")
    print_messages(run_object.get_final_state()["messages"])
# Out:
# # Run 1 {'run_id': '06763c5b-1576-4fff-ae0f-effa7edc2854', 'start_timestamp': '2025-12-24 16:03:48.499885', 'end_timestamp': '2025-12-24 16:03:54.345740', 'snapshot_counts': 5}
# Messages:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the weather like in Panaji?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 73.8333, 'lat': 15.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 25, 'feels_like': 25.46, 'temp_min': 25, 'temp_max': 25, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 3000, 'wind': {'speed': 2.06, 'deg': 20}, 'clouds': {'all': 73}, 'dt': 1766592230, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1766539674, 'sunset': 1766580019}, 'timezone': 19800, 'id': 1260607, 'name': 'Panjim', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Panaji is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 25°C
# - **Feels Like**: 25.5°C
# - **Humidity**: 73%
# - **Wind Speed**: 2.06 m/s from the northeast
# - **Visibility**: 3000 meters
# - **Cloud Cover**: 73%
#
# If you need any more information, feel free to ask!, tool_calls = None)
#
# # Run 2 {'run_id': '8fbc4a68-0e49-4899-98c3-008acfcb7f1f', 'start_timestamp': '2025-12-24 16:04:48.128285', 'end_timestamp': '2025-12-24 16:04:52.964566', 'snapshot_counts': 5}
# Messages:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the weather like in Panaji?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 73.8333, 'lat': 15.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 25, 'feels_like': 25.46, 'temp_min': 25, 'temp_max': 25, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 3000, 'wind': {'speed': 2.06, 'deg': 20}, 'clouds': {'all': 73}, 'dt': 1766592230, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1766539674, 'sunset': 1766580019}, 'timezone': 19800, 'id': 1260607, 'name': 'Panjim', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Panaji is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 25°C
# - **Feels Like**: 25.5°C
# - **Humidity**: 73%
# - **Wind Speed**: 2.06 m/s from the northeast
# - **Visibility**: 3000 meters
# - **Cloud Cover**: 73%
#
# If you need any more information, feel free to ask!, tool_calls = None)
#  -> (role = user, content = What's the weather like in Thiruvananthapuram?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 76.9167, 'lat': 8.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 27.99, 'feels_like': 31.19, 'temp_min': 27.99, 'temp_max': 27.99, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 4000, 'wind': {'speed': 0.51, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1766592289, 'sys': {'type': 1, 'id': 9226, 'country': 'IN', 'sunrise': 1766538175, 'sunset': 1766580037}, 'timezone': 19800, 'id': 1254163, 'name': 'Trivandrum', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Thiruvananthapuram is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 28°C
# - **Feels Like**: 31.2°C
# - **Humidity**: 74%
# - **Wind Speed**: 0.51 m/s (calm)
# - **Visibility**: 4000 meters
# - **Cloud Cover**: 20%
#
# If you have any other questions or need further information, just let me know!, tool_calls = None)
#
# # Run 3 {'run_id': '88b8e4ac-c269-4dc4-964d-5e1dd521acec', 'start_timestamp': '2025-12-24 16:05:16.130047', 'end_timestamp': '2025-12-24 16:05:19.652105', 'snapshot_counts': 5}
# Messages:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the weather like in Panaji?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 73.8333, 'lat': 15.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 25, 'feels_like': 25.46, 'temp_min': 25, 'temp_max': 25, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 3000, 'wind': {'speed': 2.06, 'deg': 20}, 'clouds': {'all': 73}, 'dt': 1766592230, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1766539674, 'sunset': 1766580019}, 'timezone': 19800, 'id': 1260607, 'name': 'Panjim', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Panaji is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 25°C
# - **Feels Like**: 25.5°C
# - **Humidity**: 73%
# - **Wind Speed**: 2.06 m/s from the northeast
# - **Visibility**: 3000 meters
# - **Cloud Cover**: 73%
#
# If you need any more information, feel free to ask!, tool_calls = None)
#  -> (role = user, content = What's the weather like in Thiruvananthapuram?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 76.9167, 'lat': 8.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 27.99, 'feels_like': 31.19, 'temp_min': 27.99, 'temp_max': 27.99, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 4000, 'wind': {'speed': 0.51, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1766592289, 'sys': {'type': 1, 'id': 9226, 'country': 'IN', 'sunrise': 1766538175, 'sunset': 1766580037}, 'timezone': 19800, 'id': 1254163, 'name': 'Trivandrum', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Thiruvananthapuram is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 28°C
# - **Feels Like**: 31.2°C
# - **Humidity**: 74%
# - **Wind Speed**: 0.51 m/s (calm)
# - **Visibility**: 4000 meters
# - **Cloud Cover**: 20%
#
# If you have any other questions or need further information, just let me know!, tool_calls = None)
#  -> (role = user, content = What's the exchange rate from USD to EUR?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])
#  -> (role = tool, content = "{'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1766534402, 'time_last_update_utc': 'Wed, 24 Dec 2025 00:00:02 +0000', 'time_next_update_unix': 1766620802, 'time_next_update_utc': 'Thu, 25 Dec 2025 00:00:02 +0000', 'base_code': 'USD', 'conversion_rates': {'USD': 1, 'AED': 3.6725, 'AFN': 66.0912, 'ALL': 81.9657, 'AMD': 381.3869, 'ANG': 1.79, 'AOA': 922.5811, 'ARS': 1452.25, 'AUD': 1.4938, 'AWG': 1.79, 'AZN': 1.6999, 'BAM': 1.6592, 'BBD': 2.0, 'BDT': 122.1403, 'BGN': 1.6592, 'BHD': 0.376, 'BIF': 2957.4546, 'BMD': 1.0, 'BND': 1.2853, 'BOB': 6.9204, 'BRL': 5.588, 'BSD': 1.0, 'BTN': 89.6634, 'BWP': 13.5442, 'BYN': 2.9163, 'BZD': 2.0, 'CAD': 1.3696, 'CDF': 2252.7623, 'CHF': 0.7883, 'CLF': 0.02298, 'CLP': 908.5106, 'CNH': 7.0222, 'CNY': 7.0386, 'COP': 3800.8015, 'CRC': 495.2509, 'CUP': 24.0, 'CVE': 93.5398, 'CZK': 20.6199, 'DJF': 177.721, 'DKK': 6.3313, 'DOP': 62.513, 'DZD': 129.6195, 'EGP': 47.5038, 'ERN': 15.0, 'ETB': 154.5401, 'EUR': 0.8483, 'FJD': 2.277, 'FKP': 0.7406, 'FOK': 6.3319, 'GBP': 0.7406, 'GEL': 2.6953, 'GGP': 0.7406, 'GHS': 11.3645, 'GIP': 0.7406, 'GMD': 74.2439, 'GNF': 8736.1844, 'GTQ': 7.656, 'GYD': 209.0698, 'HKD': 7.778, 'HNL': 26.3414, 'HRK': 6.3916, 'HTG': 130.8887, 'HUF': 331.3655, 'IDR': 16761.3566, 'ILS': 3.1914, 'IMP': 0.7406, 'INR': 89.6676, 'IQD': 1309.005, 'IRR': 42351.2057, 'ISK': 125.609, 'JEP': 0.7406, 'JMD': 159.4908, 'JOD': 0.709, 'JPY': 156.2209, 'KES': 128.8497, 'KGS': 87.3942, 'KHR': 4008.6044, 'KID': 1.4938, 'KMF': 417.345, 'KRW': 1480.9932, 'KWD': 0.3069, 'KYD': 0.8333, 'KZT': 509.9681, 'LAK': 21637.6656, 'LBP': 89500.0, 'LKR': 309.221, 'LRD': 176.9852, 'LSL': 16.6873, 'LYD': 5.4251, 'MAD': 9.1207, 'MDL': 16.8554, 'MGA': 4554.5991, 'MKD': 52.2523, 'MMK': 2101.1224, 'MNT': 3535.243, 'MOP': 8.0116, 'MRU': 39.8448, 'MUR': 45.9802, 'MVR': 15.45, 'MWK': 1738.7992, 'MXN': 17.9248, 'MYR': 4.0636, 'MZN': 63.7327, 'NAD': 16.6873, 'NGN': 1453.7702, 'NIO': 36.784, 'NOK': 10.0418, 'NPR': 143.4615, 'NZD': 1.7126, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.3649, 'PGK': 4.2932, 'PHP': 58.8221, 'PKR': 280.1038, 'PLN': 3.5818, 'PYG': 6773.6632, 'QAR': 3.64, 'RON': 4.3188, 'RSD': 99.6633, 'RUB': 78.1428, 'RWF': 1456.9765, 'SAR': 3.75, 'SBD': 8.0401, 'SCR': 13.9984, 'SDG': 543.6227, 'SEK': 9.1739, 'SGD': 1.2852, 'SHP': 0.7406, 'SLE': 24.1139, 'SLL': 24113.8848, 'SOS': 570.1545, 'SRD': 38.4981, 'SSP': 4619.8648, 'STN': 20.7838, 'SYP': 11027.7855, 'SZL': 16.6873, 'THB': 31.1285, 'TJS': 9.2311, 'TMT': 3.4985, 'TND': 2.8886, 'TOP': 2.3885, 'TRY': 42.8752, 'TTD': 6.7844, 'TVD': 1.4938, 'TWD': 31.5169, 'TZS': 2469.9945, 'UAH': 42.12, 'UGX': 3588.5175, 'UYU': 39.0635, 'UZS': 12073.0149, 'VES': 291.3524, 'VND': 26220.994, 'VUV': 120.5026, 'WST': 2.7512, 'XAF': 556.4599, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.7252, 'XOF': 556.4599, 'XPF': 101.2314, 'YER': 238.3491, 'ZAR': 16.6864, 'ZMW': 22.5079, 'ZWG': 26.0482, 'ZWL': 26.0482}}", tool_calls = None)
#  -> (role = assistant, content = The current exchange rate from USD to EUR is approximately **0.8483 EUR** for 1 USD. If you need any further information or have more questions, feel free to ask!, tool_calls = None)
#
# # Run 4 {'run_id': 'b88d8653-2876-4d0b-9fbd-a087b5e1e89f', 'start_timestamp': '2025-12-24 16:05:45.820269', 'end_timestamp': '2025-12-24 16:05:48.860606', 'snapshot_counts': 5}
# Messages:
#  -> (role = system, content = You are an assistant that can help with:
# 1. Getting weather information for cities
# 2. Checking currency exchange rates
# 3. Getting a random Pokemon
# Use the available tools to help answer questions about these topics.
# Maintain context across conversations within the same session., tool_calls = None)
#  -> (role = user, content = What's the weather like in Panaji?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 73.8333, 'lat': 15.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 25, 'feels_like': 25.46, 'temp_min': 25, 'temp_max': 25, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 3000, 'wind': {'speed': 2.06, 'deg': 20}, 'clouds': {'all': 73}, 'dt': 1766592230, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1766539674, 'sunset': 1766580019}, 'timezone': 19800, 'id': 1260607, 'name': 'Panjim', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Panaji is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 25°C
# - **Feels Like**: 25.5°C
# - **Humidity**: 73%
# - **Wind Speed**: 2.06 m/s from the northeast
# - **Visibility**: 3000 meters
# - **Cloud Cover**: 73%
#
# If you need any more information, feel free to ask!, tool_calls = None)
#  -> (role = user, content = What's the weather like in Thiruvananthapuram?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')])
#  -> (role = tool, content = "{'coord': {'lon': 76.9167, 'lat': 8.4833}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 27.99, 'feels_like': 31.19, 'temp_min': 27.99, 'temp_max': 27.99, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 4000, 'wind': {'speed': 0.51, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1766592289, 'sys': {'type': 1, 'id': 9226, 'country': 'IN', 'sunrise': 1766538175, 'sunset': 1766580037}, 'timezone': 19800, 'id': 1254163, 'name': 'Trivandrum', 'cod': 200}", tool_calls = None)
#  -> (role = assistant, content = The current weather in Thiruvananthapuram is as follows:
#
# - **Condition**: Haze
# - **Temperature**: 28°C
# - **Feels Like**: 31.2°C
# - **Humidity**: 74%
# - **Wind Speed**: 0.51 m/s (calm)
# - **Visibility**: 4000 meters
# - **Cloud Cover**: 20%
#
# If you have any other questions or need further information, just let me know!, tool_calls = None)
#  -> (role = user, content = What's the exchange rate from USD to EUR?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])
#  -> (role = tool, content = "{'result': 'success', 'documentation': 'https://www.exchangerate-api.com/docs', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1766534402, 'time_last_update_utc': 'Wed, 24 Dec 2025 00:00:02 +0000', 'time_next_update_unix': 1766620802, 'time_next_update_utc': 'Thu, 25 Dec 2025 00:00:02 +0000', 'base_code': 'USD', 'conversion_rates': {'USD': 1, 'AED': 3.6725, 'AFN': 66.0912, 'ALL': 81.9657, 'AMD': 381.3869, 'ANG': 1.79, 'AOA': 922.5811, 'ARS': 1452.25, 'AUD': 1.4938, 'AWG': 1.79, 'AZN': 1.6999, 'BAM': 1.6592, 'BBD': 2.0, 'BDT': 122.1403, 'BGN': 1.6592, 'BHD': 0.376, 'BIF': 2957.4546, 'BMD': 1.0, 'BND': 1.2853, 'BOB': 6.9204, 'BRL': 5.588, 'BSD': 1.0, 'BTN': 89.6634, 'BWP': 13.5442, 'BYN': 2.9163, 'BZD': 2.0, 'CAD': 1.3696, 'CDF': 2252.7623, 'CHF': 0.7883, 'CLF': 0.02298, 'CLP': 908.5106, 'CNH': 7.0222, 'CNY': 7.0386, 'COP': 3800.8015, 'CRC': 495.2509, 'CUP': 24.0, 'CVE': 93.5398, 'CZK': 20.6199, 'DJF': 177.721, 'DKK': 6.3313, 'DOP': 62.513, 'DZD': 129.6195, 'EGP': 47.5038, 'ERN': 15.0, 'ETB': 154.5401, 'EUR': 0.8483, 'FJD': 2.277, 'FKP': 0.7406, 'FOK': 6.3319, 'GBP': 0.7406, 'GEL': 2.6953, 'GGP': 0.7406, 'GHS': 11.3645, 'GIP': 0.7406, 'GMD': 74.2439, 'GNF': 8736.1844, 'GTQ': 7.656, 'GYD': 209.0698, 'HKD': 7.778, 'HNL': 26.3414, 'HRK': 6.3916, 'HTG': 130.8887, 'HUF': 331.3655, 'IDR': 16761.3566, 'ILS': 3.1914, 'IMP': 0.7406, 'INR': 89.6676, 'IQD': 1309.005, 'IRR': 42351.2057, 'ISK': 125.609, 'JEP': 0.7406, 'JMD': 159.4908, 'JOD': 0.709, 'JPY': 156.2209, 'KES': 128.8497, 'KGS': 87.3942, 'KHR': 4008.6044, 'KID': 1.4938, 'KMF': 417.345, 'KRW': 1480.9932, 'KWD': 0.3069, 'KYD': 0.8333, 'KZT': 509.9681, 'LAK': 21637.6656, 'LBP': 89500.0, 'LKR': 309.221, 'LRD': 176.9852, 'LSL': 16.6873, 'LYD': 5.4251, 'MAD': 9.1207, 'MDL': 16.8554, 'MGA': 4554.5991, 'MKD': 52.2523, 'MMK': 2101.1224, 'MNT': 3535.243, 'MOP': 8.0116, 'MRU': 39.8448, 'MUR': 45.9802, 'MVR': 15.45, 'MWK': 1738.7992, 'MXN': 17.9248, 'MYR': 4.0636, 'MZN': 63.7327, 'NAD': 16.6873, 'NGN': 1453.7702, 'NIO': 36.784, 'NOK': 10.0418, 'NPR': 143.4615, 'NZD': 1.7126, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.3649, 'PGK': 4.2932, 'PHP': 58.8221, 'PKR': 280.1038, 'PLN': 3.5818, 'PYG': 6773.6632, 'QAR': 3.64, 'RON': 4.3188, 'RSD': 99.6633, 'RUB': 78.1428, 'RWF': 1456.9765, 'SAR': 3.75, 'SBD': 8.0401, 'SCR': 13.9984, 'SDG': 543.6227, 'SEK': 9.1739, 'SGD': 1.2852, 'SHP': 0.7406, 'SLE': 24.1139, 'SLL': 24113.8848, 'SOS': 570.1545, 'SRD': 38.4981, 'SSP': 4619.8648, 'STN': 20.7838, 'SYP': 11027.7855, 'SZL': 16.6873, 'THB': 31.1285, 'TJS': 9.2311, 'TMT': 3.4985, 'TND': 2.8886, 'TOP': 2.3885, 'TRY': 42.8752, 'TTD': 6.7844, 'TVD': 1.4938, 'TWD': 31.5169, 'TZS': 2469.9945, 'UAH': 42.12, 'UGX': 3588.5175, 'UYU': 39.0635, 'UZS': 12073.0149, 'VES': 291.3524, 'VND': 26220.994, 'VUV': 120.5026, 'WST': 2.7512, 'XAF': 556.4599, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.7252, 'XOF': 556.4599, 'XPF': 101.2314, 'YER': 238.3491, 'ZAR': 16.6864, 'ZMW': 22.5079, 'ZWG': 26.0482, 'ZWL': 26.0482}}", tool_calls = None)
#  -> (role = assistant, content = The current exchange rate from USD to EUR is approximately **0.8483 EUR** for 1 USD. If you need any further information or have more questions, feel free to ask!, tool_calls = None)
#  -> (role = user, content = Pick one random Pokemon!, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_Z2kpkgHyI3po01XG60BSOXTB', function=Function(arguments='{}', name='get_random_pokemon'), type='function')])
#  -> (role = tool, content = "{'name': 'tentacruel', 'url': 'https://pokeapi.co/api/v2/pokemon/73/'}", tool_calls = None)
#  -> (role = assistant, content = You got a random Pokémon: **Tentacruel**!
#
# If you want to know more about Tentacruel or need anything else, just let me know!, tool_calls = None)

# %%
runs = agent.get_session_runs(session_id)
for run_object in runs:
    print(run_object)
    for snp in run_object.snapshots:
        print(f"-> {snp}")
    print("\n")
# Out:
# Run('06763c5b-1576-4fff-ae0f-effa7edc2854')
# -> Snapshot('a9b312b0-a9a9-4842-a3dd-df2512436fca') @ [2025-12-24 16:03:48.500056]: __entry__.State({'user_query': "What's the weather like in Panaji?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('915bcfc5-7204-48f1-aa3e-8972687a07d7') @ [2025-12-24 16:03:48.500206]: message_prep.State({'user_query': "What's the weather like in Panaji?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?")], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('44a4cf47-017e-4659-9dbc-53c1763da4a0') @ [2025-12-24 16:03:50.156675]: llm_processor.State({'user_query': "What's the weather like in Panaji?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')])], 'current_tool_calls': [ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')], 'session_id': 'external_tools'})
# -> Snapshot('35478132-de71-4aa5-b8a2-1c239b9011b3') @ [2025-12-24 16:03:50.298966]: tool_executor.State({'user_query': "What's the weather like in Panaji?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather')], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('e18d4c09-1d6d-429b-9dfb-9c730ce5152e') @ [2025-12-24 16:03:54.345706]: llm_processor.State({'user_query': "What's the weather like in Panaji?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None)], 'current_tool_calls': None, 'session_id': 'external_tools'})
#
#
# Run('8fbc4a68-0e49-4899-98c3-008acfcb7f1f')
# -> Snapshot('561057d7-07bb-40c8-be8c-27cdb8ba23c2') @ [2025-12-24 16:04:48.128465]: __entry__.State({'user_query': "What's the weather like in Thiruvananthapuram?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None)], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('49703cc6-a71d-4b48-a454-159d82c28fdd') @ [2025-12-24 16:04:48.128624]: message_prep.State({'user_query': "What's the weather like in Thiruvananthapuram?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?")], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('619a16b7-e71d-4b1d-8614-767de1926b02') @ [2025-12-24 16:04:49.493419]: llm_processor.State({'user_query': "What's the weather like in Thiruvananthapuram?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')])], 'current_tool_calls': [ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')], 'session_id': 'external_tools'})
# -> Snapshot('d6b1b2cd-b008-4bb0-b593-c0cd026e3291') @ [2025-12-24 16:04:49.631185]: tool_executor.State({'user_query': "What's the weather like in Thiruvananthapuram?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather')], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('ea3394bd-5eb9-46a1-a270-1cf5bb985a82') @ [2025-12-24 16:04:52.964530]: llm_processor.State({'user_query': "What's the weather like in Thiruvananthapuram?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None)], 'current_tool_calls': None, 'session_id': 'external_tools'})
#
#
# Run('88b8e4ac-c269-4dc4-964d-5e1dd521acec')
# -> Snapshot('7bfe1eef-c4d9-4ccb-bd46-f8c9ec76ae53') @ [2025-12-24 16:05:16.130780]: __entry__.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None)], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('4871da84-37e5-4766-913d-311d5de1d8f2') @ [2025-12-24 16:05:16.130982]: message_prep.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?")], 'current_tool_calls': None, 'session_id': 'external_tools'})
# -> Snapshot('b209d61d-79bb-4320-a2c7-2e9a49184269') @ [2025-12-24 16:05:17.186056]: llm_processor.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')])], 'current_tool_calls': [ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz' ...
# -> Snapshot('419bd5a7-3bb7-4ac2-81da-2281a7f7dbae') @ [2025-12-24 16:05:17.559914]: tool_executor.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https: ...
# -> Snapshot('be297cdd-d9cf-41ed-b30c-f3a8e22b665c') @ [2025-12-24 16:05:19.652066]: llm_processor.State({'user_query': "What's the exchange rate from USD to EUR?", 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https: ...
#
#
# Run('b88d8653-2876-4d0b-9fbd-a087b5e1e89f')
# -> Snapshot('a9389b6d-896a-4556-8872-fff5a4c47f52') @ [2025-12-24 16:05:45.820526]: __entry__.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate-ap ...
# -> Snapshot('a930916e-6bff-438d-8455-6b66fa1b1cd2') @ [2025-12-24 16:05:45.820734]: message_prep.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerate ...
# -> Snapshot('1a884671-1d90-4146-a618-1c16608d60af') @ [2025-12-24 16:05:47.139386]: llm_processor.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerat ...
# -> Snapshot('dd4a199d-d932-4644-a779-c9334bbf8457') @ [2025-12-24 16:05:47.243540]: tool_executor.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerat ...
# -> Snapshot('7b0109ff-a6a4-4acc-a0f7-fb3f46e94294') @ [2025-12-24 16:05:48.860569]: llm_processor.State({'user_query': 'Pick one random Pokemon!', 'instructions': 'You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.', 'messages': [SystemMessage(role='system', content='You are an assistant that can help with:\n1. Getting weather information for cities\n2. Checking currency exchange rates\n3. Getting a random Pokemon\nUse the available tools to help answer questions about these topics.\nMaintain context across conversations within the same session.'), UserMessage(role='user', content="What's the weather like in Panaji?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ro2udo0cQWUyZmjBliW49e1c', function=Function(arguments='{"city":"Panaji"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 73.8333, \'lat\': 15.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 25, \'feels_like\': 25.46, \'temp_min\': 25, \'temp_max\': 25, \'pressure\': 1012, \'humidity\': 73, \'sea_level\': 1012, \'grnd_level\': 1012}, \'visibility\': 3000, \'wind\': {\'speed\': 2.06, \'deg\': 20}, \'clouds\': {\'all\': 73}, \'dt\': 1766592230, \'sys\': {\'type\': 1, \'id\': 9233, \'country\': \'IN\', \'sunrise\': 1766539674, \'sunset\': 1766580019}, \'timezone\': 19800, \'id\': 1260607, \'name\': \'Panjim\', \'cod\': 200}"', tool_call_id='call_ro2udo0cQWUyZmjBliW49e1c', name='get_weather'), AIMessage(role='assistant', content='The current weather in Panaji is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 25°C\n- **Feels Like**: 25.5°C\n- **Humidity**: 73%\n- **Wind Speed**: 2.06 m/s from the northeast\n- **Visibility**: 3000 meters\n- **Cloud Cover**: 73%\n\nIf you need any more information, feel free to ask!', tool_calls=None), UserMessage(role='user', content="What's the weather like in Thiruvananthapuram?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_npaSH2xvbLpTMuA2e9ukPDB5', function=Function(arguments='{"city":"Thiruvananthapuram"}', name='get_weather'), type='function')]), ToolMessage(role='tool', content='"{\'coord\': {\'lon\': 76.9167, \'lat\': 8.4833}, \'weather\': [{\'id\': 721, \'main\': \'Haze\', \'description\': \'haze\', \'icon\': \'50n\'}], \'base\': \'stations\', \'main\': {\'temp\': 27.99, \'feels_like\': 31.19, \'temp_min\': 27.99, \'temp_max\': 27.99, \'pressure\': 1012, \'humidity\': 74, \'sea_level\': 1012, \'grnd_level\': 1011}, \'visibility\': 4000, \'wind\': {\'speed\': 0.51, \'deg\': 0}, \'clouds\': {\'all\': 20}, \'dt\': 1766592289, \'sys\': {\'type\': 1, \'id\': 9226, \'country\': \'IN\', \'sunrise\': 1766538175, \'sunset\': 1766580037}, \'timezone\': 19800, \'id\': 1254163, \'name\': \'Trivandrum\', \'cod\': 200}"', tool_call_id='call_npaSH2xvbLpTMuA2e9ukPDB5', name='get_weather'), AIMessage(role='assistant', content='The current weather in Thiruvananthapuram is as follows:\n\n- **Condition**: Haze\n- **Temperature**: 28°C\n- **Feels Like**: 31.2°C\n- **Humidity**: 74%\n- **Wind Speed**: 0.51 m/s (calm)\n- **Visibility**: 4000 meters\n- **Cloud Cover**: 20%\n\nIf you have any other questions or need further information, just let me know!', tool_calls=None), UserMessage(role='user', content="What's the exchange rate from USD to EUR?"), AIMessage(role='assistant', content=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WciRzteGtMAX0eHXCkLHIVHz', function=Function(arguments='{"from_currency":"USD"}', name='get_exchange_rate'), type='function')]), ToolMessage(role='tool', content='"{\'result\': \'success\', \'documentation\': \'https://www.exchangerat ...
